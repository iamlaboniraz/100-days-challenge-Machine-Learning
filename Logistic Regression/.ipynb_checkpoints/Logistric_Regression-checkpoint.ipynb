# %%
from sklearn.datasets import make_classification
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X,y = make_classification(n_samples=100, n_features=2,n_classes=2,n_informative=1,
                          n_redundant=0,n_clusters_per_class=1, random_state=41,)

# %%
X.shape
# Out:
# (100, 2)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y, cmap='rainbow')

# %%
# X,y = make_classification(n_samples=1000, n_features=10, n_informative=4)

# %%
# df = pd.DataFrame(X)
# df['taget'] = y

# %%
def perceptron(X,y):
    
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1
    
    for i in range(1000):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(X[j],weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]
        
    return weights[0],weights[1:]

# %%
def step(z):
    return 1 if z>0 else 0

# %%
def perceptron(X,y):
    X = np.insert(X,0,1, axis=1)
    weights = np.ones(X.shape[1])
    print()
    lr = 0.1
    for i in range(1000):
        j = np.random.randint(0,100)
        y_hat = sigmoid(np.dot(X[j], weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]
    return weights[0], weights[1:]

# %%
def sigmoid(z):
    return 1/(1+np.exp(-z))

# %%
intercept_, coef_ = perceptron(X,y)

# %%
intercept_, coef_
# Out:
# (0.6687156492002473, array([4.83418793, 0.14624777]))

# %%
coef_[0],coef_[1]
# Out:
# (4.834187927985452, 0.14624777270664657)

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
m,b
# Out:
# (-33.05477983368803, -4.5724843313791945)

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s =100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %%
# X = np.insert(X,0,1, axis=1)
# weights = np.ones(X.shape[1])
# print(weights)

# %%
# weights = np.ones(X.shape[1])
# weights

# %%
# y_hat = sigmoid(np.dot((1,0.2,0.3), weights))

# %%
# y_hat

# %%
# x = np.array([1,0.2,0.3])
# weights = weights + 0.1 *(1 - y_hat)*x
# weights

# %%
# weights[1:]

# %%
# intercept_, coef_ = perceptron(X,y)

# %%
# intercept_,coef_

# %%
# m = 2
# b = 1
# x_input1 = [0,1,2]

# %%
# import numpy as np
# x_input1 = np.linspace(-3,3,5)
# y_input1 = m*x_input1 + b

# %%
# print(x_input1)
# print(y_input1)

# %%
# np.linspace(-3,3,5)
