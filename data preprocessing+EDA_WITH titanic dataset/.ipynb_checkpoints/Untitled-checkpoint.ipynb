# %%
import pandas as pd
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/computation/expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/arrays/masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
combine = [train_df,test_df]

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(train_df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %% [markdown]
# ## Which features are categorcal??
# - Survied
# - Pclass (Ordinal)
# - Sex
# - Embarked
#
# ## Which features are numerical?
# - Age
# - Fare
# - SibSp (Discrete)
# - Parch(Discrete)

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Which features are mixed data types?
# - `Ticket` is a mix numeric and alphanumeric data types
# - `Cabin` is alphanumeric
#
# ## Which features may contain error or typos?
# - `Name` feature may contain errors or typos as there are several ways used to describe a name

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Survived feature

# %%
train_df['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %% [markdown]
# ## Family Feature

# %%
train_df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
train_df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
(train_df['Parch']==0).mean()
# Out:
# 0.7609427609427609

# %%
(train_df['SibSp']>0).mean()
# Out:
# 0.3176206509539843

# %% [markdown]
# - So, more than 75% of the passangers didn't travel with family
# - nearly 30% passengers had siblings aboard

# %% [markdown]
# ## Fare Distribution(outliers)

# %%
train_df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
# check how rare
(train_df['Fare']>500).mean()
# Out:
# 0.003367003367003367

# %% [markdown]
# - less than 1% paid high as $512

# %% [markdown]
# ## Age

# %%
train_df[(train_df['Age']>65) & (train_df['Age']<=80)].shape[0]/len(train_df)
# Out:
# 0.008978675645342313

# %% [markdown]
# - so less then 1% people was into 65-80 age

# %% [markdown]
# ## Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(train_df['Age'],bins=30)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(train_df['Fare'],bins=50)
plt.show()

# %%
sns.countplot(x='Survived',data=train_df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
train_df.describe(include=['O'])
# Out:
# /var/folders/_s/_rkc5yf52mjg60_cwkkrw5yc0000gn/T/ipykernel_2272/2257617226.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   train_df.describe(include=['O'])
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %% [markdown]
# ## Data Analysis section
# - Complete:
#   1. may want to complete `Age` features, it is definitely correlated with survived
#   2. `Embarked` may also correlated with survived and another important features.
# - Correcting:
#   1. `Ticket` feature may be dropped from our analysis since the ratio of duplicates only 22%
#   2. `Name` can be dropped due to not have standard way, and also may not contribute directly with survival
#   3. `Cabin` feature incomplete or many null values, so we can drop it too.
# - Creating:
#   1. We may create `family` feature based on `Parch` and `SibSp`
#   2. We may create a `Fare range` feature if it helps our analysis
#   3. We may create `Age bands` which can help us from continue numerical feature into ordinal categorical feature
#   4. We may create `Title` from `Name` feature

# %% [markdown]
# ## Analyze by pivoting features

# %%
train_df[['Pclass','Survived']].groupby(['Pclass'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %% [markdown]
# - significant correlation (>60%) among Pclass=1 and Survived.

# %%
train_df[['Sex','Survived']].groupby(['Sex'], as_index=False).mean().sort_values('Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %% [markdown]
# - more than 70% Survived in female although male travelled more than female

# %%
train_df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
train_df[['SibSp','Survived']].groupby(['SibSp'], as_index=False).mean().sort_values('Survived', ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
train_df[['Parch','Survived']].groupby(['Parch'], as_index=False).mean().sort_values('Survived', ascending=False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %% [markdown]
# - `SibSp` and `Parch` features have zero correlation for some values. it may be best to derive a feature or a set of features from these individual features

# %%
train_df.groupby(pd.cut(train_df['Age'], [0,5,15,25,35,60,100]))['Survived'].mean()
# Out:
# Age
# (0, 5]       0.704545
# (5, 15]      0.461538
# (15, 25]     0.344037
# (25, 35]     0.423469
# (35, 60]     0.400000
# (60, 100]    0.227273
# Name: Survived, dtype: float64

# %%
g = sns.FacetGrid(train_df, col='Survived')
g.map(plt.hist,'Age', bins=20)

# %%
grid = sns.FacetGrid(train_df, col='Survived', row='Pclass')
grid.map(plt.hist, 'Age', bins=20, alpha=0.5)
grid.add_legend()
plt.show()

# %% [markdown]
# ## Correlating categorical features

# %%
grid2 = sns.FacetGrid(train_df,row='Embarked')
grid2.map(sns.pointplot, 'Pclass','Survived', 'Sex',palette='deep')
grid2.add_legend()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the pointplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ## Correlating categorical and numerical features

# %%
grid = sns.FacetGrid(train_df, col='Survived',row='Embarked')
grid.map(sns.barplot,'Sex', 'Fare', alpha=0.5,ci=None)
grid.add_legend()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
# ...

# %% [markdown]
# ## Wrangle data
# - Based on our assumptions and decision we can drop `Cabin` and `Ticket` fetures

# %%
print('Before', train_df.shape, test_df.shape, combine[0].shape, combine[1].shape)

train_df = train_df.drop(['Cabin','Ticket'],axis=1)
test_df = test_df.drop(['Cabin','Ticket'],axis=1)
combine = [train_df,test_df]

print('After', train_df.shape, test_df.shape, combine[0].shape, combine[1].shape)
# Out:
# Before (891, 12) (418, 11) (891, 12) (418, 11)
# After (891, 10) (418, 9) (891, 10) (418, 9)

# %% [markdown]
# ## Creating new feature extracting from existing

# %%
for dataset in combine:
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.',expand=False)
pd.crosstab(train_df['Title'],train_df['Sex'])
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# /var/folders/_s/_rkc5yf52mjg60_cwkkrw5yc0000gn/T/ipykernel_2272/4093898749.py:2: SyntaxWarning: invalid escape sequence '\.'
#   dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.',expand=False)
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for dataset in combine:
    dataset['Title'] = dataset['Title'].replace(['Capt','Col','Countess','Don','Dr','Jonkheer',
                                               'Lady','Major','Rev','Sir'],'Rare')
    dataset['Title'] = dataset['Title'].replace('Mlle','Miss')
    dataset['Title'] = dataset['Title'].replace('Ms','Miss')
    dataset['Title'] = dataset['Title'].replace('Mme','Mrs')
train_df[['Title','Survived']].groupby(['Title'],as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.347826

# %%
title_mapping = {'Mr':1,'Miss':2,'Mrs':3,'Master':4,'Rare':5}
for dataset in combine:
    dataset['Title'] = dataset['Title'].map(title_mapping)
    dataset['Title']= dataset['Title'].fillna(0).astype(int)
test_df['Title'].value_counts()
# Out:
# Title
# 1    240
# 2     79
# 3     72
# 4     21
# 5      5
# 0      1
# Name: count, dtype: int64

# %%
train_df['Title'].value_counts()
# Out:
# Title
# 1    517
# 2    185
# 3    126
# 4     40
# 5     23
# Name: count, dtype: int64

# %%
combine = [train_df, test_df]

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Embarked  Title
# 0      0   7.2500        S      1
# 1      0  71.2833        C      3
# 2      0   7.9250        S      2
# 3      0  53.1000        S      3
# 4      0   8.0500        S      1

# %% [markdown]
# - Now we can drop `Name` feature into our train_df and test_df dataset and also `PassengerId` not needed in training dataset

# %%
train_df = train_df.drop(['Name','PassengerId'],axis=1)
test_df = test_df.drop(['Name'],axis=1)
combine = [train_df, test_df]

# %%
train_df.shape, test_df.shape
# Out:
# ((891, 9), (418, 9))

# %% [markdown]
# ## Converting a categorical feature

# %%
for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map({'female':1,'male':0}).astype(int)
train_df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0  22.0      1      0   7.2500        S      1
# 1         1       1    1  38.0      1      0  71.2833        C      3
# 2         1       3    1  26.0      0      0   7.9250        S      2
# 3         1       1    1  35.0      1      0  53.1000        S      3
# 4         0       3    0  35.0      0      0   8.0500        S      1

# %% [markdown]
# ## Completing a numerical continuous feature

# %%
grid = sns.FacetGrid(train_df, row='Pclass', col='Sex')
grid.map(plt.hist, 'Age')

# %%
train_df.groupby(['Sex', 'Pclass'])['Age'].median()
# Out:
# Sex  Pclass
# 0    1         40.0
#      2         30.0
#      3         25.0
# 1    1         35.0
#      2         28.0
#      3         21.5
# Name: Age, dtype: float64

# %%
import numpy as np
guess_age = np.zeros((2,3))
guess_age
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
for dataset in combine:
    for i in range(0,2):
        for j in range(0,3):
            guess_df = dataset[(dataset['Sex'] == i) & (dataset['Pclass'] == j+1) & (dataset['Age'].notnull())]['Age']
            age_guess = guess_df.median()
            guess_age[i,j] = int(age_guess / 0.5 + 0.5) * 0.5
    for i in range(0,2):
        for j in range(0,3):
            dataset.loc[ (dataset['Age'].isnull()) & (dataset['Sex'] == i) & (dataset['Pclass'] == j+1), 'Age'] = guess_age[i,j]
    dataset['Age'] = dataset['Age'].astype(int)

train_df.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0   22      1      0   7.2500        S      1
# 1         1       1    1   38      1      0  71.2833        C      3
# 2         1       3    1   26      0      0   7.9250        S      2
# 3         1       1    1   35      1      0  53.1000        S      3
# 4         0       3    0   35      0      0   8.0500        S      1

# %%
train_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       891 non-null    int64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    str
#  8   Title     891 non-null    int64
# dtypes: float64(1), int64(7), str(1)
# memory usage: 63.8 KB

# %%
test_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Sex          418 non-null    int64
#  3   Age          418 non-null    int64
#  4   SibSp        418 non-null    int64
#  5   Parch        418 non-null    int64
#  6   Fare         417 non-null    float64
#  7   Embarked     418 non-null    str
#  8   Title        418 non-null    int64
# dtypes: float64(1), int64(7), str(1)
# memory usage: 29.9 KB

# %%
train_df['AgeBand'] = pd.cut(train_df['Age'],5)
train_df[['AgeBand','Survived']].groupby('AgeBand',as_index=False).mean().sort_values('AgeBand', ascending=True)
# Out:
#          AgeBand  Survived
# 0  (-0.08, 16.0]  0.550000
# 1   (16.0, 32.0]  0.337374
# 2   (32.0, 48.0]  0.412037
# 3   (48.0, 64.0]  0.434783
# 4   (64.0, 80.0]  0.090909

# %% [markdown]
# ## replace age with ordinals based on these bands

# %%
for dataset in combine:
    dataset.loc[dataset['Age']<=16, 'Age'] = 0
    dataset.loc[(dataset['Age']>16) & (dataset['Age']<=32), 'Age'] = 1
    dataset.loc[(dataset['Age']>32) & (dataset['Age']<=48), 'Age'] = 2
    dataset.loc[(dataset['Age']>48) & (dataset['Age']<=64), 'Age'] = 3
    dataset.loc[dataset['Age']>64, 'Age'] = 4
train_df.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title  \
# 0         0       3    0    1      1      0   7.2500        S      1
# 1         1       1    1    2      1      0  71.2833        C      3
# 2         1       3    1    1      0      0   7.9250        S      2
# 3         1       1    1    2      1      0  53.1000        S      3
# 4         0       3    0    2      0      0   8.0500        S      1
#
#         AgeBand
# 0  (16.0, 32.0]
# 1  (32.0, 48.0]
# 2  (16.0, 32.0]
# 3  (32.0, 48.0]
# 4  (32.0, 48.0]

# %%
train_df['Age'].value_counts()
# Out:
# Age
# 1    495
# 2    216
# 0    100
# 3     69
# 4     11
# Name: count, dtype: int64

# %%
train_df = train_df.drop(['AgeBand'],axis=1)
combine = [train_df,test_df]
train_df.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title
# 0         0       3    0    1      1      0   7.2500        S      1
# 1         1       1    1    2      1      0  71.2833        C      3
# 2         1       3    1    1      0      0   7.9250        S      2
# 3         1       1    1    2      1      0  53.1000        S      3
# 4         0       3    0    2      0      0   8.0500        S      1

# %%
test_df.head()
# Out:
#    PassengerId  Pclass  Sex  Age  SibSp  Parch     Fare Embarked  Title
# 0          892       3    0    2      0      0   7.8292        Q      1
# 1          893       3    1    2      1      0   7.0000        S      3
# 2          894       2    0    3      0      0   9.6875        Q      1
# 3          895       3    0    1      0      0   8.6625        S      1
# 4          896       3    1    1      1      1  12.2875        S      3

# %% [markdown]
# ## Create new feature combining existing features

# %%
for dataset in combine:
    dataset['familySize'] = dataset['SibSp'] + dataset['Parch'] + 1
train_df[['familySize','Survived']].groupby('familySize',as_index=False).mean().sort_values('Survived', ascending=False)
# Out:
#    familySize  Survived
# 3           4  0.724138
# 2           3  0.578431
# 1           2  0.552795
# 6           7  0.333333
# 0           1  0.303538
# 4           5  0.200000
# 5           6  0.136364
# 7           8  0.000000
# 8          11  0.000000

# %%
for dataset in combine:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['familySize']== 1, 'IsAlone'] = 1
train_df[['IsAlone','Survived']].groupby('IsAlone',as_index=False).mean()
# Out:
#    IsAlone  Survived
# 0        0  0.505650
# 1        1  0.303538

# %% [markdown]
# ## Lets drop Parch, SibSp and familySize features

# %%
train_df = train_df.drop(['Parch','SibSp','familySize'], axis=1)
test_df = test_df.drop(['Parch','SibSp','familySize'], axis=1)
combine = [train_df, test_df]

train_df.head()
# Out:
#    Survived  Pclass  Sex  Age     Fare Embarked  Title  IsAlone
# 0         0       3    0    1   7.2500        S      1        0
# 1         1       1    1    2  71.2833        C      3        0
# 2         1       3    1    1   7.9250        S      2        1
# 3         1       1    1    2  53.1000        S      3        0
# 4         0       3    0    2   8.0500        S      1        1

# %%
for dataset in combine:
    dataset['Age*Class'] =  dataset.Age * dataset.Pclass
train_df.loc[:,['Age*Class','Age','Pclass']]
# Out:
#      Age*Class  Age  Pclass
# 0            3    1       3
# 1            2    2       1
# 2            3    1       3
# 3            2    2       1
# 4            6    2       3
# ..         ...  ...     ...
# 886          2    1       2
# 887          1    1       1
# 888          3    1       3
# 889          1    1       1
# 890          3    1       3
#
# [891 rows x 3 columns]

# %%
train_df[['Age*Class', 'Survived']].groupby('Age*Class',as_index=False).mean().sort_values('Survived',ascending=False)
# Out:
#    Age*Class  Survived
# 1          1  0.728814
# 0          0  0.550000
# 2          2  0.520408
# 4          4  0.415094
# 3          3  0.277487
# 5          6  0.149425
# 7          9  0.111111
# 6          8  0.000000
# 8         12  0.000000

# %%
freq_port = train_df.Embarked.dropna().mode()[0]
freq_port
# Out:
# 'S'

# %%
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].fillna(freq_port)

train_df[['Embarked','Survived']].groupby('Embarked',as_index=False).mean()
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.339009

# %% [markdown]
# ## convert categorical feature to numeric

# %%
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].map({'S':0,'C':1,'Q':2}).astype(int)
train_df.head()
# Out:
#    Survived  Pclass  Sex  Age     Fare  Embarked  Title  IsAlone  Age*Class
# 0         0       3    0    1   7.2500         0      1        0          3
# 1         1       1    1    2  71.2833         1      3        0          2
# 2         1       3    1    1   7.9250         0      2        1          3
# 3         1       1    1    2  53.1000         0      3        0          2
# 4         0       3    0    2   8.0500         0      1        1          6

# %%
test_df['Fare'] = test_df['Fare'].fillna(test_df['Fare'].dropna().median())
test_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Sex          418 non-null    int64
#  3   Age          418 non-null    int64
#  4   Fare         418 non-null    float64
#  5   Embarked     418 non-null    int64
#  6   Title        418 non-null    int64
#  7   IsAlone      418 non-null    int64
#  8   Age*Class    418 non-null    int64
# dtypes: float64(1), int64(8)
# memory usage: 29.5 KB

# %%
train_df['FareBand'] = pd.qcut(train_df['Fare'],4)

# %%
train_df[['FareBand','Survived']].groupby('FareBand',as_index=False).mean().sort_values('Survived', ascending=True)
# Out:
#           FareBand  Survived
# 0   (-0.001, 7.91]  0.197309
# 1   (7.91, 14.454]  0.303571
# 2   (14.454, 31.0]  0.454955
# 3  (31.0, 512.329]  0.581081

# %%
for dataset in combine:
    dataset.loc[dataset['Fare']<=7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare']>7.91) & (dataset['Fare']<=14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare']>14.454) & (dataset['Fare']<=31), 'Fare'] = 2
    dataset.loc[(dataset['Fare']>31), 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)

train_df.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class  \
# 0         0       3    0    1     0         0      1        0          3
# 1         1       1    1    2     3         1      3        0          2
# 2         1       3    1    1     1         0      2        1          3
# 3         1       1    1    2     3         0      3        0          2
# 4         0       3    0    2     1         0      1        1          6
#
#           FareBand
# 0   (-0.001, 7.91]
# 1  (31.0, 512.329]
# 2   (7.91, 14.454]
# 3  (31.0, 512.329]
# 4   (7.91, 14.454]

# %%
train_df = train_df.drop(['FareBand'],axis=1)
combine = [train_df,test_df]
train_df.head(5)
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0         0       3    0    1     0         0      1        0          3
# 1         1       1    1    2     3         1      3        0          2
# 2         1       3    1    1     1         0      2        1          3
# 3         1       1    1    2     3         0      3        0          2
# 4         0       3    0    2     1         0      1        1          6

# %%
test_df.head(5)
# Out:
#    PassengerId  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0          892       3    0    2     0         2      1        1          6
# 1          893       3    1    2     0         0      3        0          6
# 2          894       2    0    3     1         2      1        1          6
# 3          895       3    0    1     1         0      1        1          3
# 4          896       3    1    1     1         0      3        0          3

# %% [markdown]
# ## Modeling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
X_train = train_df.drop("Survived", axis=1)
y_train = train_df['Survived']
X_test = test_df.drop("PassengerId", axis=1)

# %%
X_train.shape, y_train.shape, X_test.shape
# Out:
# ((891, 8), (891,), (418, 8))

# %% [markdown]
# ## 1. Logistic regression

# %%
loggistic_reg = LogisticRegression()
loggistic_reg.fit(X_train,y_train)
y_pred = loggistic_reg.predict(X_test)

# %%
accuracy_reg = round(loggistic_reg.score(X_train, y_train) * 100, 2)
accuracy_reg
# Out:
# 81.37

# %%
coeff_df = pd.DataFrame(train_df.columns.delete(0))
coeff_df.columns = ['Feature']
coeff_df['Coefficient'] = pd.Series(loggistic_reg.coef_[0])
coeff_df.sort_values('Coefficient', ascending=False)
# Out:
#      Feature  Coefficient
# 1        Sex     2.201033
# 5      Title     0.406095
# 4   Embarked     0.276739
# 6    IsAlone     0.185767
# 7  Age*Class    -0.050246
# 3       Fare    -0.071894
# 2        Age    -0.469586
# 0     Pclass    -1.200216

# %%
svc = SVC()
svc.fit(X_train,y_train)
y_pred = svc.predict(X_test)
accuracy_svc = round(svc.score(X_train, y_train) * 100, 2)
accuracy_svc
# Out:
# 82.83

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
accuracy_knn = round(knn.score(X_train, y_train) * 100, 2)
accuracy_knn
# Out:
# 83.84

# %%
gaussian = GaussianNB()
gaussian.fit(X_train,y_train)
y_pred = gaussian.predict(X_test)
accuracy_gaussian = round(gaussian.score(X_train, y_train) * 100, 2)
accuracy_gaussian
# Out:
# 76.88

# %%
perceptron = Perceptron()
perceptron.fit(X_train,y_train)
y_pred = perceptron.predict(X_test)
accuracy_perceptron = round(perceptron.score(X_train, y_train) * 100, 2)
accuracy_perceptron
# Out:
# 79.35

# %%
linear_svc = LinearSVC()
linear_svc.fit(X_train,y_train)
y_pred = linear_svc.predict(X_test)
accuracy_linear_svc = round(linear_svc.score(X_train, y_train) * 100, 2)
accuracy_linear_svc
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# 79.46

# %%
sgd = SGDClassifier()
sgd.fit(X_train,y_train)
y_pred = sgd.predict(X_test)
accuracy_sgd = round(sgd.score(X_train, y_train) * 100, 2)
accuracy_sgd
# Out:
# 70.48

# %%
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train,y_train)
y_pred = decision_tree.predict(X_test)
accuracy_decision_tree = round(decision_tree.score(X_train, y_train) * 100, 2)
accuracy_decision_tree
# Out:
# 86.64

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train,y_train)
y_pred = random_forest.predict(X_test)
accuracy_random_forest = round(random_forest.score(X_train, y_train) * 100, 2)
accuracy_random_forest
# Out:
# 86.64

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machine','KNN', 'Logistic Regression', 'Random Forest',
             'Naive Bayes','Perceptron','Stochastic Gradient Descent',
             'Linear SVC','Decision Tree'],
    'Score': [accuracy_svc,accuracy_knn,accuracy_reg,accuracy_random_forest,accuracy_gaussian,accuracy_perceptron,
              accuracy_sgd,accuracy_linear_svc,accuracy_decision_tree       
    ]
})
models.sort_values('Score',ascending=False)
# Out:
#                          Model  Score
# 3                Random Forest  86.64
# 8                Decision Tree  86.64
# 1                          KNN  83.84
# 0       Support Vector Machine  82.83
# 2          Logistic Regression  81.37
# 7                   Linear SVC  79.46
# 5                   Perceptron  79.35
# 4                  Naive Bayes  76.88
# 6  Stochastic Gradient Descent  70.48

# %%
submission = pd.DataFrame({
    'PassengerId': test_df['PassengerId'],
    'Survived': y_pred
})

# %%
submission.to_csv('submission.csv',index=False)
