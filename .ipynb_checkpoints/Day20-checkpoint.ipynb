# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
sns.countplot(x='Survived', data=df_train);

# %%
print(df_train.Survived.sum()/df_train.Survived.count()*100)
# Out:
# 38.38383838383838

# %%
df_train.groupby(['Survived', 'Sex'])['Survived'].count()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Survived, dtype: int64

# %%
sns.countplot(x='Pclass',data = df_train)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='Sex',data = df_train)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Embarked',data = df_train)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.catplot(x='Sex', col='Survived', kind='count', height=3,
    aspect=1 , data=df_train)

# %%
print(df_train[df_train['Sex'] == 'female']['Survived'].sum()/df_train[df_train['Sex'] == 'female']['Survived'].count()," % women survived")
print(df_train[df_train['Sex'] == 'male']['Survived'].sum()/df_train[df_train['Sex'] == 'male']['Survived'].count()," % man survived")
# Out:
# 0.7420382165605095  % women survived
# 0.18890814558058924  % man survived

# %%
f,ax=plt.subplots(1,2,figsize=(7,5))
df_train['Survived'][df_train['Sex'] == 'male'].value_counts().plot.pie(explode=[0,0.2],
                                                                        autopct='%1.1f%%',
                                                                        ax=ax[0],
                                                                        shadow=True)
df_train['Survived'][df_train['Sex'] == 'female'].value_counts().plot.pie(explode=[0,0.2],
                                                                        autopct='%1.1f%%',
                                                                        ax=ax[1],
                                                                        shadow=True)
ax[0].set_title('Survived (male)')
ax[1].set_title('Survived (female)')
plt.show()

# %%
df_train['Survived'][df_train['Sex'] == 'male'].value_counts(normalize=True) * 100
# Out:
# Survived
# 0    81.109185
# 1    18.890815
# Name: proportion, dtype: float64

# %% [markdown]
# ### Passenger class : Survival rate decreases with Pclass

# %%
pd.crosstab(df_train.Pclass, df_train.Survived, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style type="text/css">
# #T_90fa2_row0_col0, #T_90fa2_row1_col1, #T_90fa2_row1_col2 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_90fa2_row0_col1 {
#   background-color: #ffce00;
#   color: #000000;
# }
# #T_90fa2_row0_col2 {
#   background-color: #fff400;
#   color: #000000;
# }
# #T_90fa2_row1_col0 {
#   background-color: #fff600;
#   color: #000000;
# }
# #T_90fa2_row2_col0 {
#   background-color: #ff6000;
#   color: #f1f1f1;
# }
# #T_90fa2_row2_col1 {
#   background-color: #ffdf00;
#   color: #000000;
# }
# #T_90fa2_row2_col2 {
#   background-color: #ff9000;
#   color: #000000;
# }
# #T_90fa2_row3_col0, #T_90fa2_row3_col1, #T_90fa2_row3_col2 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_90fa2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_90fa2_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_90fa2_level0_col1" class="col_heading level0 col1" >1</th>
# ...

# %%
 df_train.Survived[df_train.Pclass == 1].sum()
# Out:
# 136

# %%
print('Pclass=1 : ', df_train.Survived[df_train.Pclass == 1].sum()/df_train.Survived[df_train.Pclass == 1].count()*100)
print('Pclass=1 : ', df_train.Survived[df_train.Pclass == 2].sum()/df_train.Survived[df_train.Pclass == 2].count()*100)
print('Pclass=1 : ', df_train.Survived[df_train.Pclass == 3].sum()/df_train.Survived[df_train.Pclass == 3].count()*100)
# Out:
# Pclass=1 :  62.96296296296296
# Pclass=1 :  47.28260869565217
# Pclass=1 :  24.236252545824847

# %%
sns.catplot(x='Pclass', y='Survived', kind='point',data=df_train)

# %%
pd.crosstab(df_train.Pclass, df_train.Survived, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style type="text/css">
# #T_c537d_row0_col0, #T_c537d_row1_col1, #T_c537d_row1_col2 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_c537d_row0_col1 {
#   background-color: #ffce00;
#   color: #000000;
# }
# #T_c537d_row0_col2 {
#   background-color: #fff400;
#   color: #000000;
# }
# #T_c537d_row1_col0 {
#   background-color: #fff600;
#   color: #000000;
# }
# #T_c537d_row2_col0 {
#   background-color: #ff6000;
#   color: #f1f1f1;
# }
# #T_c537d_row2_col1 {
#   background-color: #ffdf00;
#   color: #000000;
# }
# #T_c537d_row2_col2 {
#   background-color: #ff9000;
#   color: #000000;
# }
# #T_c537d_row3_col0, #T_c537d_row3_col1, #T_c537d_row3_col2 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c537d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_c537d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c537d_level0_col1" class="col_heading level0 col1" >1</th>
# ...

# %%
pd.crosstab([df_train.Sex, df_train.Survived], df_train.Pclass, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style type="text/css">
# #T_84758_row0_col0, #T_84758_row0_col1, #T_84758_row0_col3, #T_84758_row3_col2 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_84758_row0_col2, #T_84758_row1_col2 {
#   background-color: #fff100;
#   color: #000000;
# }
# #T_84758_row1_col0 {
#   background-color: #ff9600;
#   color: #000000;
# }
# #T_84758_row1_col1 {
#   background-color: #ffa300;
#   color: #000000;
# }
# #T_84758_row1_col3 {
#   background-color: #ffcf00;
#   color: #000000;
# }
# #T_84758_row2_col0 {
#   background-color: #ffa700;
#   color: #000000;
# }
# #T_84758_row2_col1, #T_84758_row2_col3 {
#   background-color: #ff8500;
#   color: #f1f1f1;
# }
# #T_84758_row2_col2 {
#   background-color: #ff6e00;
#   color: #f1f1f1;
# }
# #T_84758_row3_col0 {
#   background-color: #ffcd00;
#   color: #000000;
# }
# #T_84758_row3_col1 {
#   background-color: #fff000;
#   color: #000000;
# }
# #T_84758_row3_col3 {
#   background-color: #fff700;
#   color: #000000;
# }
# ...

# %%
sns.catplot(x='Pclass',y='Survived', hue='Sex', kind='point',data=df_train)

# %%
df_train.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
sns.catplot(x='Survived', col='Embarked', kind='count', data=df_train)

# %%
sns.catplot(x='Embarked',y='Survived', kind='point', data=df_train)

# %%
sns.catplot(x='Embarked',y='Survived', hue='Sex', kind='point',data=df_train)

# %%
sns.catplot(x='Embarked', y='Survived', col='Pclass', hue='Sex',kind='point', data=df_train)

# %%
pd.crosstab([df_train.Survived], [df_train.Sex, df_train.Pclass, df_train.Embarked], margins=True)
# Out:
# Sex      female                              male                            \
# Pclass        1         2          3            1          2          3
# Embarked      C  Q   S  C  Q   S   C   Q   S    C  Q   S   C  Q   S   C   Q
# Survived
# 0             1  0   2  0  0   6   8   9  55   25  1  51   8  1  82  33  36
# 1            42  1  46  7  2  61  15  24  33   17  0  28   2  0  15  10   3
# All          43  1  48  7  2  67  23  33  88   42  1  79  10  1  97  43  39
#
# Sex            All
# Pclass
# Embarked    S
# Survived
# 0         231  549
# 1          34  340
# All       265  889

# %%
sns.heatmap(pd.crosstab([df_train.Survived],
            [df_train.Sex, df_train.Pclass, df_train.Embarked]))
# Out:
# <Axes: xlabel='Sex-Pclass-Embarked', ylabel='Survived'>

# %%
df_test['Survived'] = 0

df_test.loc[(df_test.Sex == 'female'), 'Survived'] = 1
df_test.loc[(df_test.Sex == 'female') & (df_test.Pclass == 3) & (df_test.Embarked == 'S'),'Survived'] = 0

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q         0
# 1  47.0      1      0   363272   7.0000   NaN        S         0
# 2  62.0      0      0   240276   9.6875   NaN        Q         0
# 3  27.0      0      0   315154   8.6625   NaN        S         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         0

# %%
df_train.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df_train['Age_bin'] = np.nan

# %%
for df in [df_train, df_test]:
    df['Age_bin'] = np.nan
    for i in range(8,0,-1):
        df.loc[df['Age'] <= i*10, 'Age_bin'] = i

# %%
df_train['Age_bin']
# Out:
# 0      3.0
# 1      4.0
# 2      3.0
# 3      4.0
# 4      4.0
#       ...
# 886    3.0
# 887    2.0
# 888    NaN
# 889    3.0
# 890    4.0
# Name: Age_bin, Length: 891, dtype: float64

# %%
print(df_train[['Age', 'Age_bin','Survived']].head(10))
# Out:
#     Age  Age_bin  Survived
# 0  22.0      3.0         0
# 1  38.0      4.0         1
# 2  26.0      3.0         1
# 3  35.0      4.0         1
# 4  35.0      4.0         0
# 5   NaN      NaN         0
# 6  54.0      6.0         0
# 7   2.0      1.0         0
# 8  27.0      3.0         1
# 9  14.0      2.0         1

# %%
sns.catplot(x='Age_bin',y='Survived', hue='Sex', kind='point',data=df_train )

# %%
sns.catplot(x='Age_bin', y='Survived', col='Pclass', row='Sex', kind='point', data=df_train)

# %%
pd.crosstab([df_train.Sex, df_train.Survived],[df_train.Age_bin, df_train.Pclass], margins=True).style.background_gradient(
    cmap='autumn_r')
# Out:
# <style type="text/css">
# #T_6360c_row0_col0, #T_6360c_row1_col20, #T_6360c_row3_col19, #T_6360c_row3_col21 {
#   background-color: #ffaa00;
#   color: #000000;
# }
# #T_6360c_row0_col1, #T_6360c_row0_col3, #T_6360c_row0_col4, #T_6360c_row0_col6, #T_6360c_row0_col9, #T_6360c_row0_col10, #T_6360c_row0_col12, #T_6360c_row0_col13, #T_6360c_row0_col15, #T_6360c_row0_col17, #T_6360c_row0_col18, #T_6360c_row0_col19, #T_6360c_row0_col20, #T_6360c_row0_col21, #T_6360c_row0_col22, #T_6360c_row0_col23, #T_6360c_row1_col0, #T_6360c_row1_col11, #T_6360c_row1_col14, #T_6360c_row1_col17, #T_6360c_row1_col19, #T_6360c_row1_col21, #T_6360c_row1_col22, #T_6360c_row2_col0, #T_6360c_row2_col1, #T_6360c_row3_col2, #T_6360c_row3_col5, #T_6360c_row3_col7, #T_6360c_row3_col8, #T_6360c_row3_col13, #T_6360c_row3_col16, #T_6360c_row3_col17, #T_6360c_row3_col18, #T_6360c_row3_col20, #T_6360c_row3_col22 {
#   background-color: #ffff00;
#   color: #000000;
# }
# ...

# %% [markdown]
# For passengers in Age_bin = 1 (younger than 10) : All male in Pclass 1 and 2 survived
#
# All female in Pclass 3 and Age_bin = 5 died.
#
# (Survival rate for female in Pclass 3 and Age_bin = 4 is below 50%)
#
# (Survival rate for male in Pclass 1 and Age_bin = 4 is above 50%)

# %%
# in Pclass 1 and 2 all men in Age_bin = 1 survived

df_test.loc[(df_test.Sex == 'male') & (df_test.Pclass == 1) & (df_test.Age_bin == 1), 'Survived'] = 1
df_test.loc[(df_test.Sex == 'male') & (df_test.Pclass == 2) & (df_test.Age_bin == 1), 'Survived'] = 1

# %%
df_test.Age_bin.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 418 entries, 0 to 417
# Series name: Age_bin
# Non-Null Count  Dtype
# --------------  -----
# 332 non-null    float64
# dtypes: float64(1)
# memory usage: 3.4 KB

# %% [markdown]
# ## SibSp and Parch

# %%
sns.catplot(x='SibSp', y='Survived', col='Pclass', row='Sex', kind='point', data=df_train)

# %%
pd.crosstab([df_train.Sex, df_train.Survived], [df_train.SibSp,df_train.Pclass], margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style type="text/css">
# #T_cb565_row0_col0, #T_cb565_row0_col1, #T_cb565_row0_col2, #T_cb565_row0_col3, #T_cb565_row0_col4, #T_cb565_row0_col6, #T_cb565_row0_col7, #T_cb565_row0_col9, #T_cb565_row0_col10, #T_cb565_row0_col15, #T_cb565_row1_col13, #T_cb565_row1_col14, #T_cb565_row2_col10, #T_cb565_row3_col5, #T_cb565_row3_col8, #T_cb565_row3_col9, #T_cb565_row3_col10, #T_cb565_row3_col11, #T_cb565_row3_col12, #T_cb565_row3_col13, #T_cb565_row3_col14 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_cb565_row0_col5 {
#   background-color: #ffd900;
#   color: #000000;
# }
# #T_cb565_row0_col8 {
#   background-color: #ffdb00;
#   color: #000000;
# }
# #T_cb565_row0_col11 {
#   background-color: #ff6a00;
#   color: #f1f1f1;
# }
# #T_cb565_row0_col12 {
#   background-color: #ffd200;
#   color: #000000;
# }
# #T_cb565_row0_col13, #T_cb565_row2_col3, #T_cb565_row2_col6, #T_cb565_row3_col6 {
#   background-color: #ffcc00;
#   color: #000000;
# }
# ...

# %% [markdown]
# For males, no survival rate above 0.5 for any values of SibSp. For females, passengers with SibSp = 3
# and Pclass = 3 died, also all females with SibSp > 4 died. For females with SibSp = 1 and Pclass = 3
# survival rate is below 0.5

# %%
# survival_rates = (
#     df_train.groupby(['Sex', 'Pclass', 'SibSp'])['Survived']
#     .mean()
#     .reset_index()
# )

# %%
#  all females with SibSp > 4 died
df_test.loc[(df_test.Sex == 'female') & (df_test.SibSp > 4), 'Survived'] = 0

# %%
sns.catplot(x='Parch', 
            y='Survived', 
            col='Pclass', 
            row='Sex', 
            kind='point',
            data=df_train)

# %%
pd.crosstab(
    [df_train.Sex, df_train.Survived],
    [df_train.Parch, df_train.Pclass], margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style type="text/css">
# #T_2d91a_row0_col0, #T_2d91a_row0_col1, #T_2d91a_row0_col2, #T_2d91a_row0_col3, #T_2d91a_row0_col4, #T_2d91a_row0_col6, #T_2d91a_row0_col7, #T_2d91a_row0_col9, #T_2d91a_row0_col11, #T_2d91a_row0_col15, #T_2d91a_row1_col11, #T_2d91a_row1_col12, #T_2d91a_row1_col14, #T_2d91a_row2_col9, #T_2d91a_row2_col14, #T_2d91a_row3_col2, #T_2d91a_row3_col5, #T_2d91a_row3_col8, #T_2d91a_row3_col9, #T_2d91a_row3_col10, #T_2d91a_row3_col11, #T_2d91a_row3_col12, #T_2d91a_row3_col13, #T_2d91a_row3_col14 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_2d91a_row0_col5 {
#   background-color: #ffe400;
#   color: #000000;
# }
# #T_2d91a_row0_col8 {
#   background-color: #ffa600;
#   color: #000000;
# }
# #T_2d91a_row0_col10, #T_2d91a_row1_col10, #T_2d91a_row2_col10, #T_2d91a_row2_col12 {
#   background-color: #ffaa00;
#   color: #000000;
# }
# #T_2d91a_row0_col12 {
#   background-color: #ff5500;
#   color: #f1f1f1;
# }
# #T_2d91a_row0_col13 {
# ...

# %% [markdown]
# Very similar to SibSp - 1 , but different values ? For females with Parch = 2 and Pclass = 3 survival rate is below 0.5
# All females with Parch = 4 and Pclass = 3 died. All females with Parch > 4 died. (For females with Parch = 1 and Pclass = 3 survival rate is below 0.5) For males,all survival rates below 0.5 for any values of Parch, except for Parch = 2 and Pclass = 1.

# %%
# Survived rate is below 0.5 for female Parch=2 and Pclass=3
df_test.loc[(df_test.Sex == 'female') &  (df_test.Parch == 2) & (df_test.Pclass == 3),'Survived'] = 0

# All females with Parch = 4 and Pclass = 3 died
df_test.loc[(df_test.Sex == 'female') & (df_test.Parch == 4) & (df_test.Pclass == 3), 'Survived'] = 0

# All females with Parch > 4 died.
df_test.loc[(df_test.Sex == 'female') & (df_test.Parch > 3), 'Survived'] = 0

df_test.loc[(df_test.Sex == 'male') & (df_test.Parch == 2) & (df_test.Pclass == 1), 'Survived'] = 1

df_test.head(20)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %%
sns.distplot(df_train['Fare'])
# Out:
# /var/folders/_s/_rkc5yf52mjg60_cwkkrw5yc0000gn/T/ipykernel_4314/3175540965.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_train['Fare'])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
sns.boxplot(df_train['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
df_train['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
for df in [df_train, df_test]:
    df['Fare_bin'] = np.nan
    for i in range(12, 0, -1):
        df.loc[df['Fare'] <= i*50, 'Fare_bin' ] = i

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
sns.catplot(x='Fare_bin',y='Survived', col='Pclass' , row = 'Sex', kind='point', data=df_train)

# %%
pd.crosstab([df_train.Sex, df_train.Survived], [df_train.Fare_bin, df_train.Pclass], margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style type="text/css">
# #T_5f8a1_row0_col0, #T_5f8a1_row0_col1, #T_5f8a1_row0_col3, #T_5f8a1_row0_col4, #T_5f8a1_row0_col6, #T_5f8a1_row0_col8, #T_5f8a1_row0_col9, #T_5f8a1_row0_col10, #T_5f8a1_row0_col11, #T_5f8a1_row1_col5, #T_5f8a1_row2_col7, #T_5f8a1_row2_col10, #T_5f8a1_row3_col2, #T_5f8a1_row3_col4, #T_5f8a1_row3_col7, #T_5f8a1_row3_col8, #T_5f8a1_row3_col9 {
#   background-color: #ffff00;
#   color: #000000;
# }
# #T_5f8a1_row0_col2 {
#   background-color: #fff000;
#   color: #000000;
# }
# #T_5f8a1_row0_col5 {
#   background-color: #ffc900;
#   color: #000000;
# }
# #T_5f8a1_row0_col7 {
#   background-color: #ffdf00;
#   color: #000000;
# }
# #T_5f8a1_row1_col0 {
#   background-color: #ffde00;
#   color: #000000;
# }
# #T_5f8a1_row1_col1 {
#   background-color: #ffa300;
#   color: #000000;
# }
# #T_5f8a1_row1_col2 {
#   background-color: #ffee00;
#   color: #000000;
# }
# #T_5f8a1_row1_col3 {
#   background-color: #ff7100;
#   color: #f1f1f1;
# }
# #T_5f8a1_row1_col4 {
# ...

# %%
# males in Fare_bin = 11 survived
df_test.loc[ (df_test.Sex == 'male') & (df_test.Fare_bin == 11), 'Survived'] = 1

# %%
df_test.drop(['Survived'],axis=1,inplace=True)

# %% [markdown]
# # Part 2: Data wrangling

# %% [markdown]
# building two new dataframes df_train_ml and df_test_ml
# these will have only ordinal features and no missing values
# so they can be used for ML algorithms
# converting categorical to numerical by pd.get_dummies
# dropping all features that seem to be not useful for prediction
# Then use the Standard scaler and apply train/test split

# %%
df_train_ml = df_train.copy()
df_test_ml = df_test.copy()

# %%
df_train_ml.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Age_bin  Fare_bin
# 0      0  A/5 21171   7.2500   NaN        S      3.0       1.0
# 1      0   PC 17599  71.2833   C85        C      4.0       2.0

# %%
df_train_ml.shape
# Out:
# (891, 14)

# %% [markdown]
# pandas get_dummies for categorical features

# %%
df_train_ml = pd.get_dummies(df_train_ml, columns=['Sex', 'Embarked', 'Pclass'], drop_first=True)

df_train_ml.drop(['PassengerId','Name','Ticket','Cabin','Age_bin','Fare_bin'], axis=1, inplace=True)
df_train_ml.dropna(inplace=True)

# %%
df_train_ml.shape
# Out:
# (714, 10)

# %%
passenger_id = df_test_ml['PassengerId']
df_test_ml = pd.get_dummies(df_test_ml, columns=['Sex', 'Embarked', 'Pclass'], drop_first=True)
df_test_ml.drop(['PassengerId','Name','Ticket', 'Cabin', 'Age_bin', 'Fare_bin'],axis=1,inplace=True)

# %%
df_train_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    714 non-null    int64
#  1   Age         714 non-null    float64
#  2   SibSp       714 non-null    int64
#  3   Parch       714 non-null    int64
#  4   Fare        714 non-null    float64
#  5   Sex_male    714 non-null    bool
#  6   Embarked_Q  714 non-null    bool
#  7   Embarked_S  714 non-null    bool
#  8   Pclass_2    714 non-null    bool
#  9   Pclass_3    714 non-null    bool
# dtypes: bool(5), float64(2), int64(3)
# memory usage: 37.0 KB

# %%
df_test_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         332 non-null    float64
#  1   SibSp       418 non-null    int64
#  2   Parch       418 non-null    int64
#  3   Fare        417 non-null    float64
#  4   Sex_male    418 non-null    bool
#  5   Embarked_Q  418 non-null    bool
#  6   Embarked_S  418 non-null    bool
#  7   Pclass_2    418 non-null    bool
#  8   Pclass_3    418 non-null    bool
# dtypes: bool(5), float64(2), int64(2)
# memory usage: 15.2 KB

# %% [markdown]
# ## Correlation Matrix

# %%
corr = df_train_ml.corr()
f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot=True, linewidths=1.5, fmt='.2f',  ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# ## sklearn StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df_train_ml.drop('Survived', axis=1))
scaled_features = scaler.transform(df_train_ml.drop('Survived', axis=1))

df_train_ml_sc = pd.DataFrame(scaled_features, columns=df_train_ml.columns[1:])

# for df_test_ml
df_test_ml.fillna(df_test_ml.mean(), inplace=True)
scaled_features = scaler.transform(df_test_ml)
df_test_ml_sc = pd.DataFrame(scaled_features, columns=df_test_ml.columns)

# %%
df_train_ml_sc
# Out:
#           Age     SibSp     Parch      Fare  Sex_male  Embarked_Q  Embarked_S  \
# 0   -0.530377  0.524570 -0.505895 -0.518978  0.759051   -0.202031    0.537409
# 1    0.571831  0.524570 -0.505895  0.691897 -1.317434   -0.202031   -1.860779
# 2   -0.254825 -0.551703 -0.505895 -0.506214 -1.317434   -0.202031    0.537409
# 3    0.365167  0.524570 -0.505895  0.348049 -1.317434   -0.202031    0.537409
# 4    0.365167 -0.551703 -0.505895 -0.503850  0.759051   -0.202031    0.537409
# ..        ...       ...       ...       ...       ...         ...         ...
# 709  0.640719 -0.551703  5.357890 -0.105320 -1.317434    4.949747   -1.860779
# 710 -0.185937 -0.551703 -0.505895 -0.410245  0.759051   -0.202031    0.537409
# 711 -0.737041 -0.551703 -0.505895 -0.088774 -1.317434   -0.202031    0.537409
# 712 -0.254825 -0.551703 -0.505895 -0.088774  0.759051   -0.202031   -1.860779
# 713  0.158503 -0.551703 -0.505895 -0.509523  0.759051    4.949747   -1.860779
#
#      Pclass_2  Pclass_3
# ...

# %%
df_test_ml_sc
# Out:
#           Age     SibSp     Parch      Fare  Sex_male  Embarked_Q  Embarked_S  \
# 0    0.330723 -0.551703 -0.505895 -0.508025  0.759051    4.949747   -1.860779
# 1    1.191823  0.524570 -0.505895 -0.523705 -1.317434   -0.202031    0.537409
# 2    2.225142 -0.551703 -0.505895 -0.472885  0.759051    4.949747   -1.860779
# 3   -0.185937 -0.551703 -0.505895 -0.492267  0.759051   -0.202031    0.537409
# 4   -0.530377  0.524570  0.666862 -0.423718 -1.317434   -0.202031    0.537409
# ..        ...       ...       ...       ...       ...         ...         ...
# 413  0.039505 -0.551703 -0.505895 -0.503850  0.759051   -0.202031    0.537409
# 414  0.640719 -0.551703 -0.505895  1.403231 -1.317434   -0.202031   -1.860779
# 415  0.606275 -0.551703 -0.505895 -0.518978  0.759051   -0.202031    0.537409
# 416  0.039505 -0.551703 -0.505895 -0.503850  0.759051   -0.202031    0.537409
# 417  0.039505  0.524570  0.666862 -0.233279  0.759051   -0.202031   -1.860779
#
#      Pclass_2  Pclass_3
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df_train_ml.drop('Survived', axis=1),
    df_train_ml['Survived'],
    test_size=0.30, random_state=101
)

X_train_sc, X_test_sc, y_train_sc, y_test_sc = train_test_split(
    df_train_ml_sc,
    df_train_ml['Survived'],
    test_size=0.30, random_state=101
)

# %%
# unscaled
X_train_all = df_train_ml.drop('Survived', axis=1)
y_train_all = df_train_ml['Survived']
X_test_all = df_test_ml

# scaled
X_train_all_sc = df_train_ml_sc
y_train_all_sc = df_train_ml['Survived']
X_test_all_sc = df_test_ml_sc

# %%
X_test_all.fillna(X_test_all.mean(), inplace=True)
print("*")
# Out:
# *

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(max_iter=1000)
logreg.fit(X_train, y_train)
pred_logreg = logreg.predict(X_test)
print(confusion_matrix(y_test, pred_logreg))
print(classification_report(y_test, pred_logreg))
print(accuracy_score(y_test, pred_logreg))
# Out:
# [[105  18]
#  [ 28  64]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82       123
#            1       0.78      0.70      0.74        92
#
#     accuracy                           0.79       215
#    macro avg       0.78      0.77      0.78       215
# weighted avg       0.79      0.79      0.78       215
#
# 0.786046511627907

# %%
logreg.fit(X_train_all, y_train_all)
pred_all_logreg = logreg.predict(X_test_all)

# %%
sub_logreg = pd.DataFrame()
sub_logreg['PassengerId'] = df_test['PassengerId']
sub_logreg['Survived'] = pred_all_logreg
sub_logreg.to_csv('logisticmodel.csv', index=False)

# %% [markdown]
# ## Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(X_train, y_train)
pred_gnb = gnb.predict(X_test)

print(confusion_matrix(y_test, pred_gnb))
print(classification_report(y_test, pred_gnb))
print(accuracy_score(y_test, pred_gnb))
# Out:
# [[107  16]
#  [ 36  56]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.87      0.80       123
#            1       0.78      0.61      0.68        92
#
#     accuracy                           0.76       215
#    macro avg       0.76      0.74      0.74       215
# weighted avg       0.76      0.76      0.75       215
#
# 0.7581395348837209

# %% [markdown]
# ##  KNN - KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=20)
knn.fit(X_train_sc, y_train_sc)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
pred_knn = knn.predict(X_test)
print(confusion_matrix(y_test, pred_knn))
print(classification_report(y_test, pred_knn))
print(accuracy_score(y_test, pred_knn))
# Out:
# [[71 52]
#  [26 66]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.58      0.65       123
#            1       0.56      0.72      0.63        92
#
#     accuracy                           0.64       215
#    macro avg       0.65      0.65      0.64       215
# weighted avg       0.66      0.64      0.64       215
#
# 0.6372093023255814

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtree = dtree.predict(X_test)
print(classification_report(y_test, pred_dtree))
print(accuracy_score(y_test, pred_dtree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.84      0.80       123
#            1       0.75      0.65      0.70        92
#
#     accuracy                           0.76       215
#    macro avg       0.76      0.74      0.75       215
# weighted avg       0.76      0.76      0.76       215
#
# 0.7581395348837209

# %%
dtree_2 = DecisionTreeClassifier(max_features=7,max_depth=6, min_samples_split=8)
dtree_2.fit(X_train, y_train)
pred_dtree_2 = dtree_2.predict(X_test)
print(classification_report(y_test, pred_dtree_2))
print(accuracy_score(y_test, pred_dtree_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.89      0.83       123
#            1       0.81      0.66      0.73        92
#
#     accuracy                           0.79       215
#    macro avg       0.80      0.77      0.78       215
# weighted avg       0.79      0.79      0.79       215
#
# 0.7906976744186046

# %%
dtree_2.fit(X_train_all, y_train_all)
pred_all_dtree2 = dtree_2.predict(X_test_all)

# %% [markdown]
# # Bar Plot (Numerical - categorical)

# %% [markdown]
# ### what is the average age of passenger traveling in them ?

# %%
df_train.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked  Age_bin  Fare_bin
# 0      0  A/5 21171  7.25   NaN        S      3.0       1.0

# %%
sns.barplot(x = 'Pclass',y = 'Age', data=df_train)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x = 'Pclass',y = 'Fare', data=df_train, hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# # Box plot

# %%
sns.boxplot(x='Sex', y='Age', hue='Survived', data=df_train)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # Distplot (Numerical - categorical)

# %%
sns.distplot(df_train[df_train['Survived'] == 0]['Age'], hist=False)
sns.distplot(df_train[df_train['Survived'] == 1]['Age'], hist=False)
# Out:
# /var/folders/_s/_rkc5yf52mjg60_cwkkrw5yc0000gn/T/ipykernel_4314/1572717868.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_train[df_train['Survived'] == 0]['Age'], hist=False)
# /var/folders/_s/_rkc5yf52mjg60_cwkkrw5yc0000gn/T/ipykernel_4314/1572717868.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ## HeatMap (Categorical - Categorical)

# %%
pd.crosstab(df_train['Pclass'],df_train['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(df_train['Pclass'],df_train['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %% [markdown]
# ## Find percentage of people survived or not survived

# %%
df_train.groupby('Pclass')['Survived'].mean() * 100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
(df_train.groupby('Sex')['Survived'].mean() * 100).plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# ## ClusterMap (Categorical - Categorical)

# %%
sns.clustermap(pd.crosstab(df_train['Parch'], df_train['Survived']))

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(df_train,hue='Survived')

# %%
df_train.pivot_table(values='Sex', index='Pclass', columns='Survived',aggfunc='count')
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(df_train.pivot_table(values='Sex',index='Pclass', columns='Survived',aggfunc='count'))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
sns.clustermap(df_train.pivot_table(values='Sex',index='Pclass', columns='Survived',aggfunc='count'))
